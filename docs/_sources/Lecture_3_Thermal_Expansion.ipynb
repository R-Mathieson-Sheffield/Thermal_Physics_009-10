# %% [markdown]
# (TPS_Topic3)=
# # Thermal Expansion, The Kelvin Scale and Thermometers

# %% [markdown]
# ```{admonition} Learning Objectives
# :class: tip
# By the end of this topic you should:
# - Have an understanding of thermal expansion.
# - Be familiar with different types of thermometers.
# - Be able to define the Kelvin temperature scale and and give its relationship to the Celsius scale.
# ```

# %% [markdown]
# ---
# ## Thermal Expansion
#
# In the [last topic](TPS_Topic2) we began to look at thermometry which is based on measuring thermetric properties. One such thermetric property is that of thermal expansion and contraction - the change in dimensions of an object as a function of its temperature. This is one of the topics that we are going to look at today.
#
# Understanding thermal expansions is not only limited to thermometry, but also in everyday life and how we engineer the world around us. For example, consider the climate in the UK, the coldest temperature ever recorded was $-27.2\,^\circ\text{C}$ and the hottest ever recorded temperature was $40.3\,^\circ\text{C}$. This is a temperature difference of $67.5\,^\circ\text{C}$!
#
# When engineers are designing infrastructure projects, considerations must be taken to account for the fact that the infrastructure will need to operate in vastly different temperature ranges without failure.  An example of this is shown below where the design of a bridge incorporates an expansion joint, which prevents the bridge from buckling in high temperatures as it has been designed to accommodate a thermal expansion.
#
# ```{figure} Figures/ThermalExpansionExamples.png
# :name: fig_ThermalExpansionExamples
# :alt: There are two photograph images presented. The left is a close-up of an expansion joint on a bridge. The joint consists of a series of metal plates with gaps between them, allowing the bridge to expand and contract with changes in temperature. The right is a photograph of a railroad track winding through a rural landscape. The track curves gently through fields and trees.
# :width: 80%
# :align: center
# Two real world examples of thermal expansion. The left image shows an expansion joint on a bridge, allowing for thermal expansion and contraction of the bridge deck. The right is a railroad track with that should be a lot straighter but thes image shows a railroad track with several curves, demonstrating how the track has warped as it tries to exapand but has buckled instead.
# ```
#
# Similarly, we can see an example of where train tracks have buckled. Network rail aims to prevent buckling by painting some rails paler colours so they absorb less heat, reduce the speed at which trains can travel over rails in hot conditions and introduce small gaps in the rails for them to expand into. Even so this is not always sufficient, and tracks may need replacing, which means that trains are unable to run and the efficiency of the network is reduced.
#
# Let us now consider the physics that is actually taking place when materials undergo thermal expansion.
#
# To understand thermal expansion, we must look at the bulk materials on a much smaller scale. Let us consider a block of metal - if we zoom in on the structure of the metal we will find atoms arranged within a lattice (a repeating structural unit of atoms):
#
# ```{figure} Figures/CuLattice.png
# :name: fig_CuLattice
# :alt: A diagram representing the crystal lattice structure of copper. Large, overlapping spheres represent copper ions arranged in a repeating cubic pattern. Smaller black dots are scattered between the copper ions, labeled as "free electrons." Lines connect the copper ions, indicating the metallic bonds between them.
# :width: 60%
# :align: center
# Diagram illustrating the crystal lattice structure of copper. Copper ions are shown as large spheres arranged in a cubic pattern. Smaller black dots represent free electrons moving freely between the copper ions. The black lines show the bonds between copper ions.
# ```
#
#
# As these atoms have energy, they will vibrate around their equilibrium positions. If these are supplied with more heat (e.g. from the environment on a hot sunny day), the temperature of the metal will increase.
#
# As we learnt in the last lecture, temperature is directly related to the kinetic energy of the atoms, and if this increases, so does the amplitude of the atomic oscillations. This results in a larger average distance between the atoms and correspondingly and expansion of the metal.
#
# We can again assume that over a given temperature range, the amount of expansion is linearly proportional to the temperature of the material. We can also assume that the expansion would be proportional to the original length of the material. These assumptions can be expressed mathematically as:
#
# \begin{align*}
# \Delta L \propto L_0 \Delta T
# \end{align*}
#
# where $\Delta L$ is the change in length, $L_0$ is the intial length and $\Delta T$ is the change in temperature. When we see a proportionality sign we can introduce a constant of linear proportionality, which in this case is the coefficient of thermal exapansion, $\alpha$:
#
# ```{math}
# :label: eq_thermexp
# \Delta L = L_f - L_0 &= \alpha L_0 \Delta T\\
# \therefore L_f &= \alpha L_0 \Delta T + L_0\\
#     &= L_0 \left(1 + \alpha \Delta T\right)
# ```
# **We must be aware that as was the case in our thermometer example, this condition is only true over a given range of temperatures. For much larger changes in temperature, we may no longer be able to assume linear proportionality.**
#
# ---

# %% [markdown]
# ### Coefficient of Thermal Expansion
#
# The coefficient of thermal expansion of a given material can easily be calculated by rearranging equation {eq}`eq_thermexp`:
#
# \begin{align*}
# \alpha = \frac{\Delta L}{L_0 \Delta T}
# \end{align*}
#
# If we rearrange our equation we can see that $\alpha$ is simply a measure of the fractional change in length for a given change in temperature. Again, we are making an assumption that this coefficient of thermal expansion is constant (whereas in reality it is dependent on the temperature range, the initial temperature and other external conditions such as pressure). We will neglect this in our calculations unless otherwise stated.
#
# We can also see from the equation above that $\alpha$ has units of inverse temperature or "per Kelvin" (K$^{-1}$). Examples of the thermal expansion coefficients for various materials are provided below:
#
# ```{list-table} Some expansion coefficient values
# :header-rows: 1
# :name: tab:ExpCoeffs
# * - Material
#   - $\alpha$ (K$^{-1}$) @ 20˚C
# * - Aluminium
#   - $23.1 \times 10^{-6}$
# * - Brass
#   - $19 \times 10^{-6}$
# * - Concrete
#   - $1 2\times 10^{-6}$
# * - Glass
#   - $8.5 \times 10^{-6}$
# * - Lead
#   - $29 \times 10^{-6}$
# * - Mercury
#   - $61\times 10^{-6}$
# * - Titanium
#   - $8.6 \times 10^{-6}$
# ```
#
# It is worth noting that this equation holds for **all dimensions** of the material during expansion, (e.g. it could be the width, the length, the height) so long as this is a linearly expanding material. This may not always be the case, for example, some crystals when heated will expand by different amounts in different directions. We are not going to consider this additional complication.
#
# It is often necessary to use materials with similar values of thermal expansivity to prevent any thermal expansion from causing undue stresses on those materials (particularly for structural/machine components that are thermally cycled).
#
# ```{admonition} Important
#
# The equation to determine the expansion of an object for a given change in temperature is:
#
# \begin{align*}
# \Delta L = \alpha L_0 \Delta T
# \end{align*}
#
# where $\alpha$ is the coefficient of thermal expansion and has units of K$^{-1}$.
# ```
# ---

# %% [markdown]
# (TPS_Topic3_RevisitingFixedPoints)=
# ## Revisiting Fixed Points
#
# Before we move onto to looking at the different types of thermometer, it is worth revisiting the fixed points that we have used to define our tempeature scales thus far. In our previous example of making a liquid in glass thermometer using water, we stated that the two fixed points to be used were the freezing and boiling points of water, which we assigned to $0\,^\circ\text{C}$ and $100\,^\circ\text{C}$ respectively. Looking at the diagram, can you tell in which circumstances this is actually the case?
#
# ```{figure} Figures/WaterPhaseDiagram.png
# :name: fig_phase
# :alt: A phase diagram of water showing the relationship between temperature and pressure. The horizontal axis represents temperature, increasing from left to right. The vertical axis represents pressure, increasing from bottom to top. The diagram is divided into three regions; Solid, liquid, and gas. Lines and curves within the diagram indicate phase transitions, such as melting, freezing, boiling, and sublimation. Key points are labeled, including the freezing point at 1 atmosphere, the boiling point at 1 atmosphere, the critical point, and the triple point where all three phases of water can coexist.
# :width: 80%
# :align: center
# This diagram illustrates the relationship between temperature, pressure, and the phases of water (solid, liquid, and gas). Key points include the freezing point at 1 atmosphere, the boiling point at 1 atmosphere, the critical point, and the triple point where all three phases coexist.
# ```
# {numref}`fig_phase` shows us the pressure on the vertical axis and the temperature on the horizontal axis, and the different colours represent the different phases of water. The boundaries represented by the black lines represent the temperatures and pressures that phase changes occur at under different circumstances.
#
# We can see that the boiling and freezing points of water actually only occur at $0\,^\circ\text{C}$ and $100\,^\circ\text{C}$ at 1 atmosphere of pressure, and that if we increase the pressure the temperatures at which these phase transitions occur change (this is most easily seen for the boiling point).
#
# There are two other interesting points on this plot, one is the **triple point of water**, which is the temperature and pressure at which exists in solid, liquid **and** gas states.
#
# The second is the **critical point**, which is the point at which the differences in the physical properties (such as the density or the compressibility) between the liquid and vapour phase of the water become zero and the distinction between the liquid and vapour phase disappears.
#
# Taking this into consideration, it means that when we are defining the temperatures of our fixed points, there are other variables that we must be able to control for them to be truly accurate. Wouldn’t it be better if there was a more absolute temperature scale that we could use instead? Introducing the Kelvin scale!

# %% [markdown]
# ---
# ### The Kelvin Scale
#
# For the lower point we are going to recall that heat is simply equal to energy, and this energy could be extracted from an object continually to the point where there is no more energy left in the object to remove. At this point, the object will have a minimal internal energy. **We define the temperature of the object to be absolute zero - it is not possible to cool an object below this point**.
#
# It is often said that at absolute zero all molecular motion ceases, however due to the quantum nature of the universe at this scale, this is not actually true...
#
# Another quirk of absolute zero is it is actually impossible to cool an object to absolute zero in a finite number of thermodynamic steps. For example, consider if you already had an object at absolute zero and brought into contact with a body you wanted to cool to absolute zero, the two bodies would heat and cool until they reach thermal equilibrium, which will be above absolute zero. Whilst it is not possible to cool anything down to absolute zero, we have been able to cool to 38 pK (38 $\times 10^{-12}$ K!
#
# **The lower fixed point for the Kelvin scale is absolute zero!**
#
# **The upper fixed point of the Kelvin scale is the triple point of water ($0.01\,^\circ\text{C}$, $273.16\text{ K}$ at $611.657\text{ Pa}$).**
#
# Not only is the triple point of water occur at the same temperature, but this also means that we get a very simple relationship between the celsius scale and Kelvin scale. An increase in temperature of $1\,^\circ\text{C}$ is equal to an increase in $1\text{ K}$. If we need to convert between Kelvin and Celcius, we simply add 273.15 to our celsius value.
#
# For example, $0\,^\circ\text{C}$ is simply equal to $273.15\text{ K}$, $20\,^\circ\text{C}$ is simply equal to $293.15\text{ K}$. Note that we do not say "degrees Kelvin", simply Kelvin!
#
#
# ---

# %% [markdown]
# ## Types of Thermometer
#
# Let us consider the different types of thermometer, with their advantages and disadvantages. The choice of thermometer you would use is dependent on many circumstances such as how hot the thing we are measuring is likely to be (e.g. sticking a glass thermometer into molten lava will not end well...)? Is the temperature probe going to be incorporated into a small device? etc.
#
# When we defined our temperature scale, we assumed that the thermometric property we were measuring was changing linearly with the temperature. On this basis, we used two fixed points to define an equation that gave us a relationship between the temperature and thermometric property, however **most thermometric properties don’t change linearly with temperature, or they only do so over a limited range!**
#
# ---

# %% [markdown]
# ### Liquid in Glass Thermometer
#
# We know that these operate via the expansion of a liquid as a function of temperature, the liquids most commonly being used are mercury or ethanol, due to the fact that both of these liquids will undergo phase changes, they are only able to measure over a limited range of temperature.
#
# The design of these thermometers means that they are very sensitive to changes in temperature. Simply consider a cylinder with a fixed cross-sectional area, $A$, containing a liquid. If the cylinder has large cross sectional area, as the volume of the liquid expands the increase in the length of the liquid in the cylinder will barely change, whereas if the cross sectional area of the tube is very narrow, a small fluctuation in temperature will correspond to a large change in the length of the liquid! This means that these thermometers are very sensitive to changes in temperature. The change in length of the material can be calculated as:
#
# \begin{align*}
# \Delta L = \frac{\Delta V}{A}
# \end{align*}
#
# ````{grid}
# :gutter: 2
#
# ```{grid-item-card} **Advantages:**
# - They are portable.
# - They allow for direct reading.
# - There is no need to re-calibrate over the lifetime of the device.
# - They are relatively cheap.
# ```
# ```{grid-item-card} **Disadvantages:**
# - They are not very accurate.
# - They only measure temperatures over a limited range.
# - Mercury is toxic if the thermometer breaks.
# ```
# ````

# %% [markdown]
# ---
# ### Platinum Resistance Thermometer
#
# As we have discussed previously, the electrical resistivity of a material is a thermometric property and the one that is exploited in platinum resistance thermometers - this is to say that the measured resistance of the device changes as a function of its temperature. There are two common standards:
#
# - PT100 has a resistance of $100\,\Omega$ at $100\,^\circ\text{C}$.
# - PT1000 has a resistance of $1000\,\Omega$ at $100\,^\circ\text{C}$.
#
# ```{figure} Figures/PTResistance.png
# :name: PTResistance
# :alt: A photograph of a Pt100 RTD temperature sensor. The sensor consists of a long, thin metal probe with a cylindrical head. The head of the sensor contains the sensing element, which is a platinum resistor that changes resistance with temperature.
# :width: 100%
# :align: center
# A standard PT100 RTD (Resistance Temperature Detector) probe.
# ```
#
# Platinum is chosen because of its relatively high resistivity and wide temperature range as well as for being stable, this means that the temperature probe is able to operate over a large range of temperatures with a relatively high sensitivity to changes in temperature and accuracy when measuring temperatures. The final advantage is that it is a digital device which means that it may be more useful for recording temperatures in an experiment.
#
# The conversion between the resistance and temperature for a PT100 thermometer is:
# \begin{align*}
# R(T) = R_{100}\left[1 + \rho_T(T-100)\right]
# \end{align*}
# where $\rho_T$ is the thermal resistivity of platinum (units of ohms per Kelvin), $R_{100}$ the resistance of the thermometer at $100\,^\circ\text{C}$, and $T$ measured in $^\circ\text{C}$. Notice that this is very similar to the form in {eq}`eq_thermexp`, and the equation follows a simple $y = mx + c$ form (once the brackets are expanded, and noting that the change in temperature here is with respect to $100\,^\circ\text{C}$), meaning that the response is assumed to be linear.
#
# ````{grid}
# :gutter: 2
# ```{grid-item-card} **Advantages:**
# - They can operates over a wide range of temperatures.
# - They are very sensitive and accurate.
# - They allow for direct temperature to voltage conversion (digital means no need to take manual measurements).
# ```
# ```{grid-item-card} **Disadvantages:**
# - The coil type has a very slow response.
# - At low temperatures, resistive heating can lead to inaccuracies.
# ```
# ````

# %% [markdown]
# ---
# ### Thermistor Resistance Thermometer
#
# A similar resistive thermometer is a thermistor, however unlike the previous resistive thermometer the temperature response is not linear.
#
# ```{figure} Figures/ThermistorResistance.png
# :name: ThermistorResistance
# :alt: Left image shows a graph showing the relationship between resistance and temperature. The horizontal axis is labeled temperature, increasing from left to right. The  vertical axis is labeled resistance, increasing from bottom to top. A blue line curves downward from left to right, indicating that resistance decreases as temperature increases. The graph is titled "Resistance (Ω) vs. Temperature (°C)" and includes the label "10 kilo-ohm at 25 degree C Thermistor." Right image shows a photograph of two thermistors. Thermistors are small electronic components used to measure temperature. They are shaped like beads with two metal leads extending from them. The thermistors in the image are black and green in color.
# :width: 80%
# :align: center
# Left: A graph showing the relationship between resistance and temperature for a $10\text{ k}\Omega$ at $25\,^\circ\text{C}$ thermistor. The graph demonstrates the negative temperature coefficient (NTC) behavior of the thermistor, where resistance decreases as temperature increases.
# Right: A photograph of two NTC thermistors with different temperature-resistance profiles.
# ```
# ````{grid}
# :gutter: 2
# ```{grid-item-card} **Advantages:**
# - They can have a very small size.
# - They have a very quick response time.
# - They allow for direct temperature to voltage conversion
# ```
# ```{grid-item-card} **Disadvantages:**
# - They need to be calibrated regularly.
# - Their temperature response is not linear.
# ```
# ````
# ---

# %% [markdown]
# ### Thermocouple Thermometer
#
# The thermocouple thermometer is another type of digital thermometer that is formed of two pieces of electrically conductive metal which have different electrical properties. These metals form a junction. As a result of the Seebeck effect, these devices produce a temperature dependant voltage at the junction.
#
# The Seebeck effect is simply an effect where an electromotive force (EMF) forms across two points of a conductor when they are at different temperatures. The magnitude of the EMF is temperature dependent which means that this thermometric property can be used for thermometry in a thermocouple thermometer.  The voltage, $V$, is used to calculate a distant temperature, provided that a reference temperature is known.
#
# ```{figure} Figures/Thermocouple.png
# :name: Thermocouple
# :alt: A yellow digital multimeter with a knob for selecting different measurement functions. The display shows a temperature reading of 0.19 degrees Celsius. A type K thermocouple probe is connected to the multimeter. The thermocouple probe has a thin, metal wire with a colored tip that is sensitive to temperature changes.
# :width: 80%
# :align: center
# A digital multimeter with a type K thermocouple probe attached. Type K thermocouple is a type of temperature sensor that measures temperature by producing a voltage proportional to the temperature difference between its two junctions.
# ```
#
# ````{grid}
# :gutter: 2
# ```{grid-item-card} **Advantages:**
# - They have a small size.
# - They have a rapid response.
# - They can operate over a very wide range of temperatures.
# - They are useful in instrumenting “hot” objects.
# ```
# ```{grid-item-card} **Disadvantages:**
# - They are not as accurate as platinum resistance thermometers.
# - Measured temperature determined using a reference temperature that itself is often determined using another thermometer. Therefore the accuracy of the measured temperature is dependent on the accuracy of the measured reference temperature.
# ```
# ````
# ---

# %% [markdown]
# ### Constant Volume Gas Thermometer
#
# In order to understand how a constant volume gas thermometer works, we must first understand one of the gas laws, which we will visit later in this course. Effectively Gay-Lussac’s Law states that the pressure of a gas held within a constant volume will increase as a function of temperature and that the pressure is directly proportional to the Kelvin temperature.
#
# ```{figure} Figures/ConstantGasVolume.png
# :name: ConstantGasVolume
# :alt: A diagram illustrating a U-shaped manometer used to measure pressure. The manometer consists of a U-shaped tube filled with mercury. One end of the tube is open to the atmosphere, while the other end is connected to a chamber containing the gas whose pressure is to be measured. The height difference between the mercury levels in the two arms of the U-tube indicates the pressure difference between the gas and the atmosphere.
# :width: 80%
# :align: center
# A diagram (top) and schematic (bottom) of a U-tube manometer used to measure pressure. As the gas expands the mercury is displaced further along the tube.
# ```
#
# Using this law we are able to make measurements of temperature using the setup shown. Here we have a bulb containing a gas submerged in the environment we are going to measure. This gas bulb is directly connected to a column of mercury that is again directly connected to a second reservoir of mercury.
#
# We aim to maintain the level of the mercury in the first column (A) relative to an external scale by moving the mercury in the second column (B). As the gas heats, it pushes the mercury in the first column down and increases the level of the mercury in the second column. Once equilibrium has been reached, the second column (B) is physically raised until the mercury in the first column returns to its original position. This ensures that as the gas heats up, the volume it occupies remains constant and the pressure of the gas increases.  The difference in height of the mercury of the second column (B) is then recorded.
#
# This means that the height of the mercury in the second reservoir is directly proportional to the pressure of the gas in the fixed volume, which itself is directly proportional to the temperature of the environment being measured.
#
# I recommend watching [this clip](https://www.youtube.com/watch?v=n0xAQXL905c) of somebody using one of these thermometers to help clarify the explaination above.
#
# ````{grid}
# :gutter: 2
# ```{grid-item-card} **Advantages:**
# - They can operate over a very large range of temperatures.
# - They are highly sensitive to changes in temperature.
# - They are very accurate.
# - The pressure changes linearly with temperature.
# ```
# ```{grid-item-card} **Disadvantages:**
# - They are cumbersome to operate.
# - They have a slow response.
# - Use requires a skilled operator.
# - There is no direct temperature to voltage conversion.
# ```
# ````
# ---

# %% [markdown]
# ### Radiation Pyrometry
#
# Our final way of measuring temperature is via pyrometry, which is the technique we used to measure extremely high temperatures where it is not physically possible to get a thermometer into contact with the body.
#
# This technique effectively uses the light emitted by the hot body to determine its temperature, for example an optical pyrometer will focus the light emitted by the glowing body onto a photodiode, which then produces a voltage proportional to the temperature of the object.
#
# A more analogue example of a pyrometer is that of the disappearing filament. Effectively, as we increase the current flowing through a filament of wire, we increase its temperature and cause it to glow due to resistive heating. The higher the current, the more brightly the filament will glow! If we then place this filament in front of the object whose temperature we would like to gauge, we can adjust the current until the glow of the filament matches that of the hot object and they become indistinguishable from one another. The current flowing through the wire is then a measure of the temperature of the object.
#
# The advantage of using pyrometers is that as they are non-contact, they do not change the temperature of the thing that you are measuring, they can be operated safely as they do not need to be directly exposed to high temperatures which may damage them and they respond to changes in temperature relatively quickly.

# %% [markdown]
# ## Questions

# %% [markdown]
# `````{admonition} Question 3.1 - Expansion of a known metal rod
# :class: dropdown, hint
#
# ````{tab-set}
# ```{tab-item} Question
# A $30\text{ cm}$ long rod of brass, initially at $20\,^\circ\text{C}$, increases in temperature by $38\,^\circ\text{C}$. By how much does the length of the rod increase?
# ```
#
# ```{tab-item} Hint
# The change in length of a solid or liquid is proportional to the change in temperature.
# ```
#
# ```{tab-item} Solution
# To answer this question we simply use the equation:
#
# \begin{align*}
# \Delta L = \alpha L_0 \Delta T
# \end{align*}
#
# We can find the thermal expansion coefficient for brass from {numref}`tab:ExpCoeffs` ($\alpha = 19 \times 10^{-6} \text{ K}^{-1}$). Entering the values into the equation gives:
#
# \begin{align*}
# \Delta L &= 19 \times 10^{-6} \times 0.30 \times 38\\
#     &= 0.22 \times 10^{-3}\text{ m}\\
#     &= 0.22\text{ mm}
# \end{align*}
# ```
# ````
# `````

# %% [markdown]
# `````{admonition} Question 3.2 - Determining type of material through thermal expansion.
# :class: dropdown, hint
#
# ````{tab-set}
# ```{tab-item} Question
# A $40\text{ cm}$ rod of unknown material, initially at $20\,^\circ\text{C}$, increases in temperature to $24.0\,^\circ\text{C}$ and expands by $1.376 \times 10^{-5}\text{ m}$. What material is the rod made from?
# ```
#
# ```{tab-item} Hint
# The change in length of a solid or liquid is proportional to the change in temperature, so the ratio of the two is the constant of proportionality which depends on the material.
# ```
#
# ```{tab-item} Solution
# To determine what the material is, we must determine its thermal expansion coefficient. Thus we use the equation:
#
# \begin{align*}
# \alpha = \frac{\Delta L}{L_0 \Delta T}
# \end{align*}
#
# Substituting in the known values gives:
#
# \begin{align*}
# \alpha &= \frac{1.376 \times 10^{-5}}{0.40 \times (24.0-20.0)}\\
#     &= 8.6 \times 10^{-6}\text{ K}^{-1}
# \end{align*}
#
# Looking at the {numref}`tab:ExpCoeffs`, this is the thermal expansion coefficient of Titanium.
# ```
# ````
# `````
